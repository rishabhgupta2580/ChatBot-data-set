# %%
import json
import pandas as pd

# %%
path = open(r'C:\Users\Rishabh Gupta\Downloads\banking_IN.json','r')

# %%
data = json.loads(path.read())

# %%
from itertools import chain, starmap

def flatten_json_iterative_solution(dictionary):
    
    def unpack(parent_key, parent_value):
        
        if isinstance(parent_value, dict):
            for key, value in parent_value.items():
                temp1 = parent_key + '_' + key
                yield temp1, value
        elif isinstance(parent_value, list):
            i = 0 
            for value in parent_value:
                temp2 = parent_key + '_'+str(i) 
                i += 1
                yield temp2, value
        else:
            yield parent_key, parent_value    

    while True:
        dictionary = dict(chain.from_iterable(starmap(unpack, dictionary.items())))
        if not any(isinstance(value, dict) for value in dictionary.values()) and \
           not any(isinstance(value, list) for value in dictionary.values()):
            break

    return dictionary

# %%
df = pd.Series(flatten_json_iterative_solution(data)).to_frame()

# %%
df
# Out:
#                                                                               0
# intents_0_intent                                                     discoTerms
# intents_0_examples_0_text                           Can I select my EMI amount?
# intents_0_examples_1_text     I have not received any letter asking my confi...
# intents_0_examples_2_text     Why I am not able to select loan tenure below ...
# intents_0_examples_3_text      If I Pay some Lumpsum amout ,will my EMI reduce?
# ...                                                                         ...
# dialog_nodes_164_dialog_node                               node_8_1470165051121
# learningOptOut                                                            False
# name                                                  watson-banking-chatbot-IN
# language                                                                     en
# description                                         A cognitive banking chatbot
#
# ...

# %%
file=open(r'C:\Users\Rishabh Gupta\Documents\results.txt', 'a+')

# %%
for i in df.index:
    file.write("%s ,"%df[0][i])

# %%
file.close()

# %%
import nltk
import numpy as np

# %%
file_content = open(r'C:\Users\Rishabh Gupta\Documents\results.txt').read()
tokens = nltk.word_tokenize(file_content)
print(tokens.head())
# Out:
# ['discoTerms', ',', 'Can', 'I', 'select', 'my', 'EMI', 'amount', '?', ',', 'I', 'have', 'not', 'received', 'any', 'letter', 'asking', 'my', 'confirmation', ',', 'Why', 'I', 'am', 'not', 'able', 'to', 'select', 'loan', 'tenure', 'below', '6', 'month', '?', ',', 'If', 'I', 'Pay', 'some', 'Lumpsum', 'amout', ',', 'will', 'my', 'EMI', 'reduce', '?', ',', 'Can', 'I', 'get', 'credit', 'of', 'loan', 'amount', 'in', 'Account', 'other', 'than', 'mentioned', 'on', 'the', 'screen', ',', 'Can', 'I', 'enter', 'a', 'mobile', 'number', 'other', 'than', 'the', 'one', 'used', 'for', 'downloading', 'the', 'app', '.', ',', 'Can', 'I', 'avail', '2', 'Pre-approved', 'Loans', ',', 'Can', 'FATCA', 'status', 'be', 'updated', 'later', '?', ',', 'Is', 'the', 'Interest', 'rate', 'fixed', 'or', 'floating', '?', ',', 'Why', 'I', 'am', 'not', 'able', 'to', 'select', 'loan', 'amount', 'below', '25000', '?', ',', 'Which', 'Branch', 'do', 'I', 'have', 'to', 'go', 'for', 'signing', 'the', 'documents', '?', ',', 'What
# ...

# %%
from nltk.stem import PorterStemmer
ps= PorterStemmer()
for w in tokens:
    stemmed=[]
    stemmed.append(ps.stem(w))
    print(stemmed)
# Out:
# ['discoterm']
# [',']
# ['can']
# ['I']
# ['select']
# ['my']
# ['emi']
# ['amount']
# ['?']
# [',']
# ['I']
# ['have']
# ['not']
# ['receiv']
# ['ani']
# ['letter']
# ['ask']
# ['my']
# ['confirm']
# [',']
# ['whi']
# ['I']
# ['am']
# ['not']
# ['abl']
# ['to']
# ['select']
# ['loan']
# ['tenur']
# ['below']
# ['6']
# ['month']
# ['?']
# [',']
# ['If']
# ['I']
# ['pay']
# ['some']
# ['lumpsum']
# ['amout']
# [',']
# ['will']
# ['my']
# ['emi']
# ['reduc']
# ['?']
# [',']
# ['can']
# ['I']
# ['get']
# ['credit']
# ['of']
# ['loan']
# ['amount']
# ['in']
# ['account']
# ['other']
# ['than']
# ['mention']
# ['on']
# ['the']
# ['screen']
# [',']
# ['can']
# ['I']
# ['enter']
# ['a']
# ['mobil']
# ['number']
# ['other']
# ['than']
# ['the']
# ['one']
# ['use']
# ['for']
# ['download']
# ['the']
# ['app']
# ['.']
# [',']
# ['can']
# ['I']
# ['avail']
# ['2']
# ['pre-approv']
# ['loan']
# [',']
# ['can']
# ['fatca']
# ['statu']
# ['be']
# ['updat']
# ['later']
# ['?']
# [',']
# ['Is']
# ...

# %%
print(stopwords.words('english'))
# Out:
# ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', "you're", "you've", "you'll", "you'd", 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', "she's", 'her', 'hers', 'herself', 'it', "it's", 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', "that'll", 'these', 'those', 'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such', 'no', 'nor', 'not', 'only', 'own', 'same', 'so', 'than',
# ...

# %%
from nltk.corpus import stopwords 
stop_words = set(stopwords.words('english')) 

filtered_sentence = [] 
  
for w in stemmed: 
    if w not in stop_words: 
        filtered_sentence.append(w) 
   
print(filtered_sentence)
# Out:
# [',']
